# %%
import pandas as pd
import pymongo as mg
client = mg.MongoClient(host='mongodb://localhost:27017')

# %%
database = client['project_data_analystics']

# %%
collection = database['review']

# %%
cursor = collection.find({})

# %%
data_list = list(cursor)

# %%
df_review = pd.DataFrame(data_list)
df_review
# Out:
#                              _id      writer  \
# 0       65098d07c0f914f394935fd9  Google 사용자
# 1       65098d07c0f914f394935fda  Google 사용자
# 2       65098d07c0f914f394935fdb  Google 사용자
# 3       65098d07c0f914f394935fdc         한반도
# 4       65098d07c0f914f394935fdd         나수인
# ...                          ...         ...
# 964779  650a5533929ca87734ce9bf3         하병철
# 964780  650a5533929ca87734ce9bf4  Google 사용자
# 964781  650a5533929ca87734ce9bf5  Google 사용자
# 964782  650a5533929ca87734ce9bf6  Google 사용자
# 964783  650a5533929ca87734ce9bf7  Google 사용자
#
#                                                      text  \
# 0       입장방식은 변경됐는데 어플은 여전히 바코드만 보여집니다. 짐에서는 더이상 바코드스캔...
# 1       정말 답답하네요 하나. GPS 100프로 신뢰하나요? 시설선택목록에서 안보임 4월말...
# 2       입장하려다 시설검색이 안되서 결국 다른곳에 입장했습니다. 기존에 잘 쓰던 앱이 업데...
# 3       평소 이동이 잦고 여러장소에서 운동하는걸 좋아하는 저에게는 합리적인 아이코젠이 정말...
# 4       아이코젠 덕분에 운동이 더 즐겁고 꾸준하게 하게 되었어요. 사용기록이 꼼꼼히 남고 ...
# ...                                                   ...
# ...

# %% [markdown]
# ### 전처리

# %%
df_review.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 964784 entries, 0 to 964783
# Data columns (total 4 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   _id     964784 non-null  object
#  1   writer  964784 non-null  object
#  2   text    964784 non-null  object
#  3   star    964784 non-null  object
# dtypes: object(4)
# memory usage: 29.4+ MB

# %%
# null값처리
df_review.isnull().sum()
# Out:
# _id       0
# writer    0
# text      0
# star      0
# dtype: int64

# %%
# 중복 처리
df_review = df_review.drop_duplicates(subset=['text'])
df_review
# Out:
#                              _id      writer  \
# 0       65098d07c0f914f394935fd9  Google 사용자
# 1       65098d07c0f914f394935fda  Google 사용자
# 2       65098d07c0f914f394935fdb  Google 사용자
# 3       65098d07c0f914f394935fdc         한반도
# 4       65098d07c0f914f394935fdd         나수인
# ...                          ...         ...
# 962027  650a5533929ca87734ce9133  Google 사용자
# 962368  650a5533929ca87734ce9288  Google 사용자
# 962710  650a5533929ca87734ce93de  Google 사용자
# 964435  650a5533929ca87734ce9a9b  Google 사용자
# 964783  650a5533929ca87734ce9bf7  Google 사용자
#
#                                                      text  \
# 0       입장방식은 변경됐는데 어플은 여전히 바코드만 보여집니다. 짐에서는 더이상 바코드스캔...
# 1       정말 답답하네요 하나. GPS 100프로 신뢰하나요? 시설선택목록에서 안보임 4월말...
# 2       입장하려다 시설검색이 안되서 결국 다른곳에 입장했습니다. 기존에 잘 쓰던 앱이 업데...
# 3       평소 이동이 잦고 여러장소에서 운동하는걸 좋아하는 저에게는 합리적인 아이코젠이 정말...
# 4       아이코젠 덕분에 운동이 더 즐겁고 꾸준하게 하게 되었어요. 사용기록이 꼼꼼히 남고 ...
# ...                                                   ...
# ...

# %% [markdown]
# ### CSV

# %%
df_review.to_csv('../../datasets/hyein_mongoDB.csv')

# %%
pd.read_csv('../../datasets/hyein_mongoDB.csv')
# Out:
#       Unnamed: 0                       _id      writer  \
# 0              0  65098d07c0f914f394935fd9  Google 사용자
# 1              1  65098d07c0f914f394935fda  Google 사용자
# 2              2  65098d07c0f914f394935fdb  Google 사용자
# 3              3  65098d07c0f914f394935fdc         한반도
# 4              4  65098d07c0f914f394935fdd         나수인
# ...          ...                       ...         ...
# 1089      962027  650a5533929ca87734ce9133  Google 사용자
# 1090      962368  650a5533929ca87734ce9288  Google 사용자
# 1091      962710  650a5533929ca87734ce93de  Google 사용자
# 1092      964435  650a5533929ca87734ce9a9b  Google 사용자
# 1093      964783  650a5533929ca87734ce9bf7  Google 사용자
#
#                                                    text                  star
# 0     입장방식은 변경됐는데 어플은 여전히 바코드만 보여집니다. 짐에서는 더이상 바코드스캔...  별표 5개 만점에 1개를 받았습니다.
# 1     정말 답답하네요 하나. GPS 100프로 신뢰하나요? 시설선택목록에서 안보임 4월말...  별표 5개 만점에 1개를 받았습니다.
# ...
