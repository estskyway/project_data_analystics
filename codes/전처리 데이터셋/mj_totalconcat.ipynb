# %%
import pandas as pd

# %%
df_total = pd.read_csv('../../datasets/DB_Total.csv')
df_total[:5]
# Out:
#    Unnamed: 0                       _id        name  \
# 0           0  651277e7ddb81e8e96c6bcbb  Google 사용자
# 1           1  651277e7ddb81e8e96c6bcbc  Google 사용자
# 2           2  651277e7ddb81e8e96c6bcbd  Google 사용자
# 3           3  651277e7ddb81e8e96c6bcbe         한반도
# 4           4  651277e7ddb81e8e96c6bcbf         나수인
#
#                                              reviews                 stars
# 0  입장방식은 변경됐는데 어플은 여전히 바코드만 보여집니다. 짐에서는 더이상 바코드스캔...  별표 5개 만점에 1개를 받았습니다.
# 1  정말 답답하네요 하나. GPS 100프로 신뢰하나요? 시설선택목록에서 안보임 4월말...  별표 5개 만점에 1개를 받았습니다.
# 2  입장하려다 시설검색이 안되서 결국 다른곳에 입장했습니다. 기존에 잘 쓰던 앱이 업데...  별표 5개 만점에 1개를 받았습니다.
# 3  평소 이동이 잦고 여러장소에서 운동하는걸 좋아하는 저에게는 합리적인 아이코젠이 정말...  별표 5개 만점에 5개를 받았습니다.
# 4  아이코젠 덕분에 운동이 더 즐겁고 꾸준하게 하게 되었어요. 사용기록이 꼼꼼히 남고 ...  별표 5개 만점에 5개를 받았습니다.

# %%
# 불용어 사전 불러오기
df_replaces = pd.read_excel('../../datasets/replace_concat.xlsx')
df_replaces[:5]
# Out:
#   before_replacement after_replacement
# 0                선생님               강사님
# 1                  샘               강사님
# 2                  쌤               강사님
# 3                 로긴               로그인
# 4                 ㅡㅡ              별로에요

# %%
from mecab import MeCab
mecab = MeCab()
replaces = df_replaces['after_replacement'].values
# 토크나이징 함수 정의(한자 이상 적용, 불용어 삭제)
def tokenizer(raw, replace=replaces):
    result_list = list()
    for word in mecab.nouns(raw) :
        if len(word) > 1 and word not in replace :
            result_list.append(word)
    # 일부 경우(토큰 갯수 제한)
    # if len(result_list) <= 3 or len(result_list) < 12 :
    #   result_list
    return ' '.join(result_list) # return str
# Out:
# array(['강사님', '강사님', '강사님', '로그인', '별로에요', '개선', '개선', '개선', '개선', '개선',
#        '개선', '개선', '개선', '좋아요', '좋아요', '좋아요', '좋아요', '좋아요', '좋아요', '좋아요',
#        '좋아요', '좋아요', '좋아요', '좋아요', '좋아요', '좋아요', '좋아요', '사이트', '사이트',
#        '사이트', '사이트', '사이트', '사이트', '사이트', '사이트', '사이트', '사이트', '사이트',
#        '사이트', '사이트', '사이트', '사이트', '사이트', '사이트', '운동시설', '운동시설', '운동시설',
#        '운동시설', '운동시설', '운동시설', '운동시설', '운동시설', '운동시설', '운동시설', '운동시설',
#        '운동시설', '운동시설', '운동시설', '운동시설', '운동시설', '스마트폰', '스마트폰', '스마트폰',
#        '스마트폰', '그룹운동', '스마트폰', '스마트폰', '스마트폰', '스마트폰', '스마트폰', '웨어러블',
#        '연동', '사운드', '갯수', '갯수', '활동량', '활동량', '환불', '디테일', '스마트폰', '웨어러블',
#        '웨어러블', '퍼스널트레이닝', '물건', '푸쉬업', '푸쉬업', '푸쉬업', '페이스북', '업데이트',
#        '푸쉬업', '푸쉬업', '푸쉬업', '푸쉬업', '화이팅', '웨어러블', '코칭', '아이템', '아이템',
#        '아이템', '포인트', '컵량', '컵량', '포인트', '포인트', '포인트', '리뷰', '칼로리량',
#        '칼로리량', '채팅방', '채팅방', '카카오톡', '채팅방', '카카오톡', '수면', '초등학생', '리셋',
# ...
