# %% [markdown]
# ### 디비 끌고오기

# %%
import pandas as pd
import pymongo as mg
client = mg.MongoClient(host='mongodb://localhost:27017')

# %%
database = client['project_data_analytics']
collection = database['googlestore_gym']

# %%
cursor = collection.find({})

# %%
data_list = list(cursor)

# %%
df_review = pd.DataFrame(data_list)
df_review
# Out:
#                           _id              name           date  \
# 0    650978afe0993aa0485ff5df  Party Saurus Rex    2023년 8월 1일
# 1    650978afe0993aa0485ff5e0          cha park   2022년 3월 29일
# 2    650978afe0993aa0485ff5e1               박나래    2021년 1월 5일
# 3    650978afe0993aa0485ff5e2               조정호    2020년 9월 2일
# 4    650978afe0993aa0485ff5e3               정희정   2020년 7월 29일
# ..                        ...               ...            ...
# 755  650bc100f544fae38f2597c5        Google 사용자  2018년 11월 30일
# 756  650bc100f544fae38f2597c6        Google 사용자  2018년 11월 26일
# 757  650bc100f544fae38f2597c7        Google 사용자   2019년 7월 25일
# 758  650bc100f544fae38f2597c8        Say Cheese   2021년 3월 21일
# 759  650bc100f544fae38f2597c9        Google 사용자  2018년 11월 28일
#
#                                                content  \
# 0    헬스장과 어플의 수익분배가 어떻게 되는지는 모르겠는데, 다짐어플로 통합회원권 끊고 ...
# 1    운동을 좋아하는사람에겐 최고입니다! 너무 잘 사용하고있어 단점이라기보단 이런점이 있...
# ...

# %% [markdown]
# ### 전처리

# %%
# null값처리
df_review.isnull().sum()
# Out:
# _id        0
# name       0
# date       0
# content    0
# reply      0
# dtype: int64

# %%
df_review = df_review.drop_duplicates()
df_review
# Out:
#                           _id              name           date  \
# 0    650978afe0993aa0485ff5df  Party Saurus Rex    2023년 8월 1일
# 1    650978afe0993aa0485ff5e0          cha park   2022년 3월 29일
# 2    650978afe0993aa0485ff5e1               박나래    2021년 1월 5일
# 3    650978afe0993aa0485ff5e2               조정호    2020년 9월 2일
# 4    650978afe0993aa0485ff5e3               정희정   2020년 7월 29일
# ..                        ...               ...            ...
# 755  650bc100f544fae38f2597c5        Google 사용자  2018년 11월 30일
# 756  650bc100f544fae38f2597c6        Google 사용자  2018년 11월 26일
# 757  650bc100f544fae38f2597c7        Google 사용자   2019년 7월 25일
# 758  650bc100f544fae38f2597c8        Say Cheese   2021년 3월 21일
# 759  650bc100f544fae38f2597c9        Google 사용자  2018년 11월 28일
#
#                                                content  \
# 0    헬스장과 어플의 수익분배가 어떻게 되는지는 모르겠는데, 다짐어플로 통합회원권 끊고 ...
# 1    운동을 좋아하는사람에겐 최고입니다! 너무 잘 사용하고있어 단점이라기보단 이런점이 있...
# ...

# %% [markdown]
# ### 저 ~ 장 ~ ㄴㄱ

# %%
df_review.to_csv('../../datasets/googlestore_preprocessed')

# %%
pd.read_csv('../../datasets/googlestore_preprocessed')
# Out:
#      Unnamed: 0                       _id              name           date  \
# 0             0  650978afe0993aa0485ff5df  Party Saurus Rex    2023년 8월 1일
# 1             1  650978afe0993aa0485ff5e0          cha park   2022년 3월 29일
# 2             2  650978afe0993aa0485ff5e1               박나래    2021년 1월 5일
# 3             3  650978afe0993aa0485ff5e2               조정호    2020년 9월 2일
# 4             4  650978afe0993aa0485ff5e3               정희정   2020년 7월 29일
# ..          ...                       ...               ...            ...
# 755         755  650bc100f544fae38f2597c5        Google 사용자  2018년 11월 30일
# 756         756  650bc100f544fae38f2597c6        Google 사용자  2018년 11월 26일
# 757         757  650bc100f544fae38f2597c7        Google 사용자   2019년 7월 25일
# 758         758  650bc100f544fae38f2597c8        Say Cheese   2021년 3월 21일
# 759         759  650bc100f544fae38f2597c9        Google 사용자  2018년 11월 28일
#
#                                                content  \
# ...
