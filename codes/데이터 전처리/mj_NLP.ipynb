# %% [markdown]
# ### 자연어처리

# %%
import pandas as pd
from mecab import MeCab
mecab = MeCab()
from konlpy.tag import Okt
okt = Okt()
df_reviews = pd.read_csv('../../datasets/minjeong_mongoDB.csv')
df_reviews[:1]
# Out:
#    Unnamed: 0                       _id service_name                 stars  \
# 0           0  650bb0b36fc4d13479415c96          김국빈  별표 5개 만점에 5개를 받았습니다.
#
#                                              reviews
# 0  짐박스 이용자로서 정말 편하게 잘 사용하고 있습니다. 한 가지 건의사항으로, 다른 ...

# %%
from gensim.corpora import Dictionary
from gensim.models import LdaModel # 주제어 확인

# %%
df_reviews = df_reviews['reviews'].tolist()
df_reviews
# Out:
# ['짐박스 이용자로서 정말 편하게 잘 사용하고 있습니다. 한 가지 건의사항으로, 다른 지점으로 출석할 시에 지오더 지점도 같이 자동으로 변경되면 어떨까 합니다. 간혹 다른 지점에 출석하고 나서 지오더 지점을 변경하는 걸 깜빡하고 주문하는 경우가 있었는데, 직원분께서 빠르게 주문 수정해주셨지만 지오더 지점도 같이 변경되면 좀 더 편할 것 같아요.',
#  '지금까지 경험한 헬스관련 웹중에서 최고라고 생각합니다. 멤버십구독 뿐만 아니라 동기유발 측면에서 강력한 챌린저는 나의 운동습관과 게으름을 채찍질 해주는 귀중한 선물과 같은 존재이며 나의 멤버십 상태와 운동기록이 철저히 기록되어지는 부분에서는 짐박스의 자상함이 물씬 묻어나와 기분이 좋아진다. 적극 추천하고 싶어진다. 아니 추천해야만한다. 나만 건강하면 안되잖아요. 우리 모두 건강관리 잘 하자구요. 우리모두 화이팅 합시다~~^^',
#  '한달반정도 사용해보니 어플이 있어서 운동한날과 운동하지 않은 날 여부를 한 눈에 체크할 수 있어서 편리합니다. 그리고 매주 디파짓을 걸고 출석 관리하는 프로그램도 선택적으로 활용할 수 있어서 꾸준한 운동습관 만드는데도 도움이 됩니다. 현장결제한 것도 어플로 바로 연동된다면 보다 더 완벽한 앱이 될것 같습니다. 그외에는 관리하기 편리해서 좋아요~!',
#  '짐박스 신림점 이용하고 있습니다. 일단 어플로 결제하는 시스템은 처음 이용하는데 너무 편리하고 좋습니다. 입장하는 방법도 앱을 통해서 하고 있는데 매우 편리하네요. 무엇보다 가격이 너무 저렴하네요. 렉이 4개나 있고 기구도 엄청많은데 월 5만원에 락카포함이면 매우 저렴하네요. 너무 좋습니다.',
#  '짐박스 신림 2호점 정말 좋습니다. 기구도 다양하고 유산소 무산소 하는 곳도 많고 특히 웨이트 하는 곳이 분리되어 있어서 너무 좋아요! 신기한 기구들도 많구요. 탈의실도 깔끔하며 관리 잘 해주십니다. 무엇보다 카운터분들이 너무 천사이십니다. 여기서 열심히 근력 운동 해서 몸짱될게요!!',
# ...

# %%
text = ' '.join(df_reviews[:100])  # df_reviews[:100]의 각 요소들을 공백으로 구분하여 하나의 문자열로 결합
morphs_list = okt.morphs(text)  # 토큰화
print(morphs_list)
# Out:
# ['짐', '박스', '이용자', '로서', '정말', '편하게', '잘', '사용', '하고', '있습니다', '.', '한', '가지', '건의', '사항', '으로', ',', '다른', '지점', '으로', '출석', '할', '시', '에', '지오', '더', '지점', '도', '같이', '자동', '으로', '변경', '되면', '어떨까', '합니다', '.', '간혹', '다른', '지점', '에', '출석', '하고', '나서', '지오', '더', '지점', '을', '변경', '하는', '걸', '깜빡', '하고', '주문', '하는', '경우', '가', '있었는데', ',', '직원', '분', '께서', '빠르게', '주문', '수정', '해주셨지만', '지오', '더', '지점', '도', '같이', '변경', '되면', '좀', '더', '편할', '것', '같아요', '.', '지금', '까지', '경험', '한', '헬스', '관련', '웹', '중', '에서', '최고', '라고', '생각', '합니다', '.', '멤버십', '구독', '뿐', '만', '아니라', '동기유발', '측면', '에서', '강력한', '챌', '린저', '는', '나', '의', '운동', '습관', '과', '게으름', '을', '채찍', '질', '해주는', '귀중한', '선물', '과', '같은', '존재', '이며', '나', '의', '멤버십', '상태', '와', '운동', '기록', '이', '철저히', '기록', '되어지는', '부분', '에서는', '짐', '박스', '의', '자상함이', '물씬', '묻어나와', '기분', '이', '좋아진다', '.', '적극', '추천', '하고', '싶어진다', '.', '아니', '추천', '해야만한', '다', '.', '나', '만', '건강하면', '안되잖아요', '.', '우리', '모두', '건강', '관리', '잘', '하자구요', '.', '우리', '모두', '화이팅'
# ...

# %%
okt.pos(df_reviews[1])
# Out:
# [('지금', 'Noun'),
#  ('까지', 'Josa'),
#  ('경험', 'Noun'),
#  ('한', 'Josa'),
#  ('헬스', 'Noun'),
#  ('관련', 'Noun'),
#  ('웹', 'Noun'),
#  ('중', 'Suffix'),
#  ('에서', 'Josa'),
#  ('최고', 'Noun'),
#  ('라고', 'Josa'),
#  ('생각', 'Noun'),
#  ('합니다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('멤버십', 'Noun'),
#  ('구독', 'Noun'),
#  ('뿐', 'Noun'),
#  ('만', 'Josa'),
#  ('아니라', 'Adjective'),
#  ('동기유발', 'Noun'),
#  ('측면', 'Noun'),
#  ('에서', 'Josa'),
#  ('강력한', 'Adjective'),
#  ('챌', 'Verb'),
#  ('린저', 'Noun'),
#  ('는', 'Josa'),
#  ('나', 'Noun'),
#  ('의', 'Josa'),
#  ('운동', 'Noun'),
#  ('습관', 'Noun'),
#  ('과', 'Josa'),
#  ('게으름', 'Noun'),
#  ('을', 'Josa'),
#  ('채찍', 'Noun'),
#  ('질', 'Noun'),
#  ('해주는', 'Verb'),
#  ('귀중한', 'Adjective'),
#  ('선물', 'Noun'),
#  ('과', 'Josa'),
#  ('같은', 'Adjective'),
#  ('존재', 'Noun'),
#  ('이며', 'Josa'),
#  ('나', 'Noun'),
#  ('의', 'Josa'),
#  ('멤버십', 'Noun'),
#  ('상태', 'Noun'),
#  ('와', 'Josa'),
#  ('운동', 'Noun'),
#  ('기록', 'Noun'),
#  ('이', 'Josa'),
#  ('철저히', 'Adjective'),
# ...

# %%
result = okt.nouns(text)
print(result)
# Out:
# ['짐', '박스', '이용자', '로서', '정말', '사용', '가지', '건의', '사항', '다른', '지점', '출석', '시', '지오', '더', '지점', '자동', '변경', '간혹', '다른', '지점', '출석', '지오', '더', '지점', '변경', '걸', '깜빡', '주문', '경우', '직원', '주문', '수정', '지오', '더', '지점', '변경', '좀', '더', '것', '지금', '경험', '헬스', '관련', '웹', '최고', '생각', '멤버십', '구독', '뿐', '동기유발', '측면', '린저', '나', '운동', '습관', '게으름', '채찍', '질', '선물', '존재', '나', '멤버십', '상태', '운동', '기록', '기록', '부분', '짐', '박스', '물씬', '기분', '적극', '추천', '추천', '나', '우리', '모두', '건강', '관리', '우리', '모두', '화이팅', '달', '정도', '사용', '어플', '운동', '날', '운동', '날', '여부', '눈', '체크', '수', '디파', '짓', '출석', '관리', '프로그램', '선택', '활용', '수', '운동', '습관', '도움', '현장', '결제', '것', '어플', '바로', '연동', '더', '앱', '외', '관리', '짐', '박스', '신림', '점', '이용', '일단', '어플', '결제', '시스템', '처음', '이용', '입장', '방법', '앱', '통해', '매우', '무엇', '가격', '렉', '개', '기구', '월', '락카', '포함', '매우', '짐', '박스', '신림', '호점', '정말', '기구', '유', '산소', '무', '산소', '곳도', '웨이', '트', '곳', '분리', '기구', '탈의실', '관리', '무엇', '카운터', '천사이십', '니', '여기', '근력', '운동', '몸짱', '공간', '기구', '강', '프리
# ...
