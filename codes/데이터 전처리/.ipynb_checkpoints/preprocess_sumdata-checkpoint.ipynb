# %%
import pandas as pd

# %%
df_one = pd.read_csv('../../datasets/hyein_mongoDB.csv')

# %% [markdown]
# ### column이름 변경

# %%
df_one.rename(columns={'writer':'name', 'text':'reviews', 'star':'stars'}, inplace=True)

# %%
df_one[:3]
# Out:
#    Unnamed: 0                       _id        name  \
# 0           0  65098d07c0f914f394935fd9  Google 사용자
# 1           1  65098d07c0f914f394935fda  Google 사용자
# 2           2  65098d07c0f914f394935fdb  Google 사용자
#
#                                              reviews                 stars
# 0  입장방식은 변경됐는데 어플은 여전히 바코드만 보여집니다. 짐에서는 더이상 바코드스캔...  별표 5개 만점에 1개를 받았습니다.
# 1  정말 답답하네요 하나. GPS 100프로 신뢰하나요? 시설선택목록에서 안보임 4월말...  별표 5개 만점에 1개를 받았습니다.
# 2  입장하려다 시설검색이 안되서 결국 다른곳에 입장했습니다. 기존에 잘 쓰던 앱이 업데...  별표 5개 만점에 1개를 받았습니다.

# %%
df_two = pd.read_csv('../../datasets/minjeong_mongoDB.csv')
df_two[:3]
# Out:
#    Unnamed: 0                       _id   service_name                 stars  \
# 0           0  650bb0b36fc4d13479415c96            김국빈  별표 5개 만점에 5개를 받았습니다.
# 1           2  650bb0b56fc4d13479415c98         율리우스시저  별표 5개 만점에 5개를 받았습니다.
# 2           5  650bb0b56fc4d13479415c9b  HYUNJUNG KWAK  별표 5개 만점에 5개를 받았습니다.
#
#                                              reviews
# 0  짐박스 이용자로서 정말 편하게 잘 사용하고 있습니다. 한 가지 건의사항으로, 다른 ...
# 1  지금까지 경험한 헬스관련 웹중에서 최고라고 생각합니다. 멤버십구독 뿐만 아니라 동기...
# 2  한달반정도 사용해보니 어플이 있어서 운동한날과 운동하지 않은 날 여부를 한 눈에 체...

# %%
df_two.rename(columns={'service_name':'name'}, inplace=True)

# %%
df_two[:3]
# Out:
#    Unnamed: 0                       _id           name                 stars  \
# 0           0  650bb0b36fc4d13479415c96            김국빈  별표 5개 만점에 5개를 받았습니다.
# 1           2  650bb0b56fc4d13479415c98         율리우스시저  별표 5개 만점에 5개를 받았습니다.
# 2           5  650bb0b56fc4d13479415c9b  HYUNJUNG KWAK  별표 5개 만점에 5개를 받았습니다.
#
#                                              reviews
# 0  짐박스 이용자로서 정말 편하게 잘 사용하고 있습니다. 한 가지 건의사항으로, 다른 ...
# 1  지금까지 경험한 헬스관련 웹중에서 최고라고 생각합니다. 멤버십구독 뿐만 아니라 동기...
# 2  한달반정도 사용해보니 어플이 있어서 운동한날과 운동하지 않은 날 여부를 한 눈에 체...

# %%
df_three = pd.read_csv('../../datasets/googlestore_preprocessed.csv')
df_three[:3]
# Out:
#    Unnamed: 0                       _id              name          date  \
# 0           0  650978afe0993aa0485ff5df  Party Saurus Rex   2023년 8월 1일
# 1           1  650978afe0993aa0485ff5e0          cha park  2022년 3월 29일
# 2           2  650978afe0993aa0485ff5e1               박나래   2021년 1월 5일
#
#                                              content  \
# 0  헬스장과 어플의 수익분배가 어떻게 되는지는 모르겠는데, 다짐어플로 통합회원권 끊고 ...
# 1  운동을 좋아하는사람에겐 최고입니다! 너무 잘 사용하고있어 단점이라기보단 이런점이 있...
# 2  오랜만에 헬스장에서 운동하고 싶은 생각에 막연하게 인터넷에 쳐보기도하고 번거롭게 전...
#
#                                                reply
# 0                                                NaN
# 1  Stone-I Co., Ltd.\n2022년 4월 12일\n안녕하세요. 운동할 땐,...
# 2  Stone-I Co., Ltd.\n2021년 3월 9일\n안녕하세요. 운동할 땐, ...

# %%
df_three.rename(columns={'content':'reviews'}, inplace=True)

# %%
df_three[:3]
# Out:
#    Unnamed: 0                       _id              name  \
# 0           0  650978afe0993aa0485ff5df  Party Saurus Rex
# 1           1  650978afe0993aa0485ff5e0          cha park
# 2           2  650978afe0993aa0485ff5e1               박나래
#
#                                              reviews
# 0  헬스장과 어플의 수익분배가 어떻게 되는지는 모르겠는데, 다짐어플로 통합회원권 끊고 ...
# 1  운동을 좋아하는사람에겐 최고입니다! 너무 잘 사용하고있어 단점이라기보단 이런점이 있...
# 2  오랜만에 헬스장에서 운동하고 싶은 생각에 막연하게 인터넷에 쳐보기도하고 번거롭게 전...

# %%
df_three = df_three.drop(columns=['date','reply'])

# %%
df_one.to_csv('../../datasets/one.csv')

# %%
df_two.to_csv('../../datasets/two.csv')

# %%
df_three.to_csv('../../datasets/three.csv')

# %% [markdown]
# ### DB Concat

# %%
import pymongo as mg

# %%
client = mg.MongoClient(host='mongodb://localhost:27017')

# %%
database = client['project_data_analytics']

# %%
collection = database['DB_concat']

# %%
cursor = collection.find({})

# %%
total = list(cursor)

# %%
total
# Out:
# [{'_id': ObjectId('65098d07c0f914f394935fd9'),
#   '': 0,
#   'Unnamed: 0': 0,
#   'name': 'Google 사용자',
#   'reviews': '입장방식은 변경됐는데 어플은 여전히 바코드만 보여집니다. 짐에서는 더이상 바코드스캔이 아닌 어플에서 입장하기로 바뀌어 사용치 못 하고 있습니다. 매달 이용료는 나가고 있는 상황이면 고쳐지기 전까지 이용못했던 일자에 대해 보상처리는 되나요?어플을 지웠다 다시 다운 받아봐도 똑같은 상태입니다. 도대체 언제부터 전 사용 가능한가요?',
#   'stars': '별표 5개 만점에 1개를 받았습니다.'},
#  {'_id': ObjectId('65098d07c0f914f394935fda'),
#   '': 1,
#   'Unnamed: 0': 1,
#   'name': 'Google 사용자',
#   'reviews': '정말 답답하네요 하나. GPS 100프로 신뢰하나요? 시설선택목록에서 안보임 4월말 업뎃이후 문제임 둘. 은행도 아닌데 로그인 타임아웃 적용하나요? 어디까지 사용자 불편을 감수하면서 가실려고.. 셋.충분하게 Test하고 업뎃적용하시는지? 근래 며칠이 멀다 화면이 바뀌는데 순전 관리용이지 고객은 안중에도 없어보임 뭐에 쫒기듯 어설프다',
#   'stars': '별표 5개 만점에 1개를 받았습니다.'},
#  {'_id': ObjectId('65098d07c0f914f394935fdb'),
#   '': 2,
#   'Unnamed: 0': 2,
#   'name': 'Google 사용자',
#   'reviews': '입장하려다 시설검색이 안되서 결국 다른곳에 입장했습니다. 기존에 잘 쓰던 앱이 업데이트 후에 매번 로그인 다시해야하고 위치 자동검색에 시설이 안나오고, 수동검색후 입장하는 기능도 없고 불편함만 늘었습니다. 덕분에 앱 여러번 삭제하고 다시까느라 애꿎은 데이타만 잔뜩쓰고 다시 예전 앱으로 돌아가고 싶습니다',
# ...

# %%
df_total = pd.DataFrame(total)

# %%
df_total
# Out:
#                            _id       Unnamed: 0        name  \
# 0     65098d07c0f914f394935fd9    0           0  Google 사용자
# 1     65098d07c0f914f394935fda    1           1  Google 사용자
# 2     65098d07c0f914f394935fdb    2           2  Google 사용자
# 3     65098d07c0f914f394935fdc    3           3         한반도
# 4     65098d07c0f914f394935fdd    4           4         나수인
# ...                        ...  ...         ...         ...
# 2873  650bc100f544fae38f2597c5  755         755  Google 사용자
# 2874  650bc100f544fae38f2597c6  756         756  Google 사용자
# 2875  650bc100f544fae38f2597c7  757         757  Google 사용자
# 2876  650bc100f544fae38f2597c8  758         758  Say Cheese
# 2877  650bc100f544fae38f2597c9  759         759  Google 사용자
#
#                                                 reviews                 stars
# 0     입장방식은 변경됐는데 어플은 여전히 바코드만 보여집니다. 짐에서는 더이상 바코드스캔...  별표 5개 만점에 1개를 받았습니다.
# 1     정말 답답하네요 하나. GPS 100프로 신뢰하나요? 시설선택목록에서 안보임 4월말...  별표 5개 만점에 1개를 받았습니다.
# ...

# %%
df_total = df_total.drop(columns=[''])
df_total
# Out:
#             name                                            reviews  \
# 0     Google 사용자  입장방식은 변경됐는데 어플은 여전히 바코드만 보여집니다. 짐에서는 더이상 바코드스캔...
# 1     Google 사용자  정말 답답하네요 하나. GPS 100프로 신뢰하나요? 시설선택목록에서 안보임 4월말...
# 2     Google 사용자  입장하려다 시설검색이 안되서 결국 다른곳에 입장했습니다. 기존에 잘 쓰던 앱이 업데...
# 3            한반도  평소 이동이 잦고 여러장소에서 운동하는걸 좋아하는 저에게는 합리적인 아이코젠이 정말...
# 4            나수인  아이코젠 덕분에 운동이 더 즐겁고 꾸준하게 하게 되었어요. 사용기록이 꼼꼼히 남고 ...
# ...          ...                                                ...
# 2873  Google 사용자                                                좋아요
# 2874  Google 사용자                                              좋아용~!
# 2875  Google 사용자                                                좋아용
# 2876  Say Cheese                                              너무느려요
# 2877  Google 사용자                                              아주좋아여
#
#                      stars
# 0     별표 5개 만점에 1개를 받았습니다.
# 1     별표 5개 만점에 1개를 받았습니다.
# 2     별표 5개 만점에 1개를 받았습니다.
# 3     별표 5개 만점에 5개를 받았습니다.
# ...

# %%
df_total.columns
# Out:
# Index(['name', 'reviews', 'stars'], dtype='object')

# %%
df_total.to_csv('../../datasets/DB_Total.csv')

# %%
pd.read_csv('../../datasets/DB_Total.csv')
# Out:
#       Unnamed: 0        name  \
# 0              0  Google 사용자
# 1              1  Google 사용자
# 2              2  Google 사용자
# 3              3         한반도
# 4              4         나수인
# ...          ...         ...
# 2873        2873  Google 사용자
# 2874        2874  Google 사용자
# 2875        2875  Google 사용자
# 2876        2876  Say Cheese
# 2877        2877  Google 사용자
#
#                                                 reviews                 stars
# 0     입장방식은 변경됐는데 어플은 여전히 바코드만 보여집니다. 짐에서는 더이상 바코드스캔...  별표 5개 만점에 1개를 받았습니다.
# 1     정말 답답하네요 하나. GPS 100프로 신뢰하나요? 시설선택목록에서 안보임 4월말...  별표 5개 만점에 1개를 받았습니다.
# 2     입장하려다 시설검색이 안되서 결국 다른곳에 입장했습니다. 기존에 잘 쓰던 앱이 업데...  별표 5개 만점에 1개를 받았습니다.
# 3     평소 이동이 잦고 여러장소에서 운동하는걸 좋아하는 저에게는 합리적인 아이코젠이 정말...  별표 5개 만점에 5개를 받았습니다.
# 4     아이코젠 덕분에 운동이 더 즐겁고 꾸준하게 하게 되었어요. 사용기록이 꼼꼼히 남고 ...  별표 5개 만점에 5개를 받았습니다.
# ...                                                 ...                   ...
# ...
