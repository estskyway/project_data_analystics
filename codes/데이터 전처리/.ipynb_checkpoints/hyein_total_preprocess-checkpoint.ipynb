# %%
import pandas as pd

# %%
df=pd.read_csv('../../datasets/DB_Total.csv')
df[:3]
# Out:
#    Unnamed: 0                       _id        name  \
# 0           0  651277e7ddb81e8e96c6bcbb  Google 사용자
# 1           1  651277e7ddb81e8e96c6bcbc  Google 사용자
# 2           2  651277e7ddb81e8e96c6bcbd  Google 사용자
#
#                                              reviews                 stars
# 0  입장방식은 변경됐는데 어플은 여전히 바코드만 보여집니다. 짐에서는 더이상 바코드스캔...  별표 5개 만점에 1개를 받았습니다.
# 1  정말 답답하네요 하나. GPS 100프로 신뢰하나요? 시설선택목록에서 안보임 4월말...  별표 5개 만점에 1개를 받았습니다.
# 2  입장하려다 시설검색이 안되서 결국 다른곳에 입장했습니다. 기존에 잘 쓰던 앱이 업데...  별표 5개 만점에 1개를 받았습니다.

# %%
# 필요없는 컬럼 삭제
df = df.drop(columns=['Unnamed: 0'], axis=1)
df[:5]
# Out:
#                         _id        name  \
# 0  651277e7ddb81e8e96c6bcbb  Google 사용자
# 1  651277e7ddb81e8e96c6bcbc  Google 사용자
# 2  651277e7ddb81e8e96c6bcbd  Google 사용자
# 3  651277e7ddb81e8e96c6bcbe         한반도
# 4  651277e7ddb81e8e96c6bcbf         나수인
#
#                                              reviews                 stars
# 0  입장방식은 변경됐는데 어플은 여전히 바코드만 보여집니다. 짐에서는 더이상 바코드스캔...  별표 5개 만점에 1개를 받았습니다.
# 1  정말 답답하네요 하나. GPS 100프로 신뢰하나요? 시설선택목록에서 안보임 4월말...  별표 5개 만점에 1개를 받았습니다.
# 2  입장하려다 시설검색이 안되서 결국 다른곳에 입장했습니다. 기존에 잘 쓰던 앱이 업데...  별표 5개 만점에 1개를 받았습니다.
# 3  평소 이동이 잦고 여러장소에서 운동하는걸 좋아하는 저에게는 합리적인 아이코젠이 정말...  별표 5개 만점에 5개를 받았습니다.
# 4  아이코젠 덕분에 운동이 더 즐겁고 꾸준하게 하게 되었어요. 사용기록이 꼼꼼히 남고 ...  별표 5개 만점에 5개를 받았습니다.

# %% [markdown]
# ### 전처리

# %% [markdown]
# #### 결측치 처리

# %%
# 결측치 -> stars는 머신러닝 학습을 통해 예측 후 생성예정
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2878 entries, 0 to 2877
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   _id      2878 non-null   object
#  1   name     2878 non-null   object
#  2   reviews  2878 non-null   object
#  3   stars    2118 non-null   object
# dtypes: object(4)
# memory usage: 90.1+ KB

# %%
df_reviews = df['reviews']
reviews_list = list(df_reviews)
reviews_list[:5]
# Out:
# ['입장방식은 변경됐는데 어플은 여전히 바코드만 보여집니다. 짐에서는 더이상 바코드스캔이 아닌 어플에서 입장하기로 바뀌어 사용치 못 하고 있습니다. 매달 이용료는 나가고 있는 상황이면 고쳐지기 전까지 이용못했던 일자에 대해 보상처리는 되나요?어플을 지웠다 다시 다운 받아봐도 똑같은 상태입니다. 도대체 언제부터 전 사용 가능한가요?',
#  '정말 답답하네요 하나. GPS 100프로 신뢰하나요? 시설선택목록에서 안보임 4월말 업뎃이후 문제임 둘. 은행도 아닌데 로그인 타임아웃 적용하나요? 어디까지 사용자 불편을 감수하면서 가실려고.. 셋.충분하게 Test하고 업뎃적용하시는지? 근래 며칠이 멀다 화면이 바뀌는데 순전 관리용이지 고객은 안중에도 없어보임 뭐에 쫒기듯 어설프다',
#  '입장하려다 시설검색이 안되서 결국 다른곳에 입장했습니다. 기존에 잘 쓰던 앱이 업데이트 후에 매번 로그인 다시해야하고 위치 자동검색에 시설이 안나오고, 수동검색후 입장하는 기능도 없고 불편함만 늘었습니다. 덕분에 앱 여러번 삭제하고 다시까느라 애꿎은 데이타만 잔뜩쓰고 다시 예전 앱으로 돌아가고 싶습니다',
#  '평소 이동이 잦고 여러장소에서 운동하는걸 좋아하는 저에게는 합리적인 아이코젠이 정말 딱입니다! 제휴 업체도 꾸준히 추가되서 새로운 업체 방문하는게 요즘 낙이네요. 입장방식도 바코드에서 GPS로 바뀌면서 좀 더 편해지고 사용자편의적으로 개선이 되어가고 있어서 좋습니다. 앞으로도 좋은 제휴업체 많이 추가해주세요!!!!',
#  '아이코젠 덕분에 운동이 더 즐겁고 꾸준하게 하게 되었어요. 사용기록이 꼼꼼히 남고 사용지점이 많아서 출장이나 본가에 가게되도 지속적으로 쓸수있는점이 짱이예요! 라이프 코스도 같이 이용중인데 덕분에 카페이용비가 확 낮아졌어요 완전 대박 😀😀']

# %% [markdown]
# #### 형태소 분석

# %%
from konlpy.tag import Komoran
komoran = Komoran()
from mecab import Mecab
mecab = Mecab()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[49], line 3
#       1 from konlpy.tag import Komoran
#       2 komoran = Komoran()
# ----> 3 from mecab import Mecab
#       4 mecab = Mecab()
#
# ModuleNotFoundError: No module named 'mecab'

# %%
# 한 문장으로 만들기
reviews = ' '.join(reviews_list)
reviews
# Out:
# '입장방식은 변경됐는데 어플은 여전히 바코드만 보여집니다. 짐에서는 더이상 바코드스캔이 아닌 어플에서 입장하기로 바뀌어 사용치 못 하고 있습니다. 매달 이용료는 나가고 있는 상황이면 고쳐지기 전까지 이용못했던 일자에 대해 보상처리는 되나요?어플을 지웠다 다시 다운 받아봐도 똑같은 상태입니다. 도대체 언제부터 전 사용 가능한가요? 정말 답답하네요 하나. GPS 100프로 신뢰하나요? 시설선택목록에서 안보임 4월말 업뎃이후 문제임 둘. 은행도 아닌데 로그인 타임아웃 적용하나요? 어디까지 사용자 불편을 감수하면서 가실려고.. 셋.충분하게 Test하고 업뎃적용하시는지? 근래 며칠이 멀다 화면이 바뀌는데 순전 관리용이지 고객은 안중에도 없어보임 뭐에 쫒기듯 어설프다 입장하려다 시설검색이 안되서 결국 다른곳에 입장했습니다. 기존에 잘 쓰던 앱이 업데이트 후에 매번 로그인 다시해야하고 위치 자동검색에 시설이 안나오고, 수동검색후 입장하는 기능도 없고 불편함만 늘었습니다. 덕분에 앱 여러번 삭제하고 다시까느라 애꿎은 데이타만 잔뜩쓰고 다시 예전 앱으로 돌아가고 싶습니다 평소 이동이 잦고 여러장소에서 운동하는걸 좋아하는 저에게는 합리적인 아이코젠이 정말 딱입니다! 제휴 업체도 꾸준히 추가되서 새로운 업체 방문하는게 요즘 낙이네요. 입장방식도 바코드에서 GPS로 바뀌면서 좀 더 편해지고 사용자편의적으로 개선이 되어가고 있어서 좋습니다. 앞으로도 좋은 제휴업체 많이 추가해주세요!!!! 아이코젠 덕분에 운동이 더 즐겁고 꾸준하게 하게 되었어요. 사용기록이 꼼꼼히 남고 사용지점이 많아서 출장이나 본가에 가게되도 지속적으로 쓸수있는점이 짱이예요! 라이프 코스도 같이 이용중인데 덕분에 카페이용비가 확 낮아졌어요 완전 대박 😀😀 작년부터 계속 이용하고 있는 아이코젠, 정말 좋아요. 축 처져있는 여름날씨에도 운동하게 만들어줘요. 앱이 누구나 알아보기 쉽고 편리하게 되어 있어요. 이용내역을 통해 내가 언제 얼마나 이용했는지 정확하게 알 수 있어서 코로나로 힘든 시국에도 편리하고 안전하게 
# ...

# %%
# 토큰화
komoran.morphs(reviews)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[52], line 2
#       1 # 토큰화
# ----> 2 komoran.morphs(reviews)
#
# File ~\anaconda3\Lib\site-packages\konlpy\tag\_komoran.py:113, in Komoran.morphs(self, phrase)
#     110 def morphs(self, phrase):
#     111     """Parse phrase to morphemes."""
# --> 113     return [s for s, t in self.pos(phrase)]
#
# File ~\anaconda3\Lib\site-packages\konlpy\tag\_komoran.py:93, in Komoran.pos(self, phrase, flatten, join)
#      91     continue
#      92 result = self.jki.analyze(sentence).getTokenList()
# ---> 93 result = [(token.getMorph(), token.getPos()) for token in result]
#      95 if join:
#      96     result = ['{}/{}'.format(morph, pos) for morph, pos in result]
#
# File ~\anaconda3\Lib\site-packages\konlpy\tag\_komoran.py:93, in <listcomp>(.0)
#      91     continue
#      92 result = self.jki.analyze(sentence).getTokenList()
# ...

# %%
# 품사달기
morphs = komoran.pos(reviews)
morphs

# %%
# 토큰화 함수
def tokenize_reviews_list(reviews):
    tokens = komoran.morphs(reviews)
    return ' '.join(tokens)

# %%
df['tokenized_review'] = df['reviews'].apply(tokenize_reviews_list)

# %%
df[:5]

# %% [markdown]
# #### 자연어 전처리

# %% [markdown]
# ##### 유사어 대치

# %%
df_replacewords = pd.read_excel('../../datasets/replace_concat.csv.xlsx')
df_replacewords[:5]

# %%
# 유사어 대치 함수
def replace_word(tokenized_review):
    replaced_review = list()
    for i in range(len(df_replacewords['before_replacement'])):
        try:
            # 치환할 단어 있는 경우에만 데이터 치환 수행
            if type(tokenized_review) == str and df_replacewords['before_replacement'][i] in tokenized_review:
                replaced_review = df_replacewords['after_replacement'][i]
            # 치환할 단어가 없는 경우에는 그대로 뱉어냄
            else :
                replaced_review = tokenized_review
        except Exception as e:
            # print(f"Error 발생 / 에러명: {e}")
            pass
    return replaced_review

# %%
# 확인
replace_word('아이코젠 운동 즐겁고 꾸준하게 하게 되었어요. 사용기록이 꼼꼼히 남고 사용지점이 많아서 출장이나 본가에 가게되도 지속적으로 쓸수있는점이 짱이예요! 라이프 코스도 같이 이용중인데 덕분에 카페이용비가 확 낮아졌어요 완전 대박 😀😀')
# Out:
# '아이코젠 운동 즐겁고 꾸준하게 하게 되었어요. 사용기록이 꼼꼼히 남고 사용지점이 많아서 출장이나 본가에 가게되도 지속적으로 쓸수있는점이 짱이예요! 라이프 코스도 같이 이용중인데 덕분에 카페이용비가 확 낮아졌어요 완전 대박 😀😀'

# %% [markdown]
# ##### 불용어 처리와 한단어 처리

# %%
# 불용어 사전 불러오기
df_stopwords = pd.read_excel('../../../../Downloads/stopword_concat.xlsx')
df_stopwords[700:710]
# Out:
#     stopword
# 700     일지라도
# 701       일차
# 702       일후
# 703  임에 틀림없다
# 704     입각하여
# 705      입니다
# 706    입장방식은
# 707      잇따라
# 708       있고
# 709       있는

# %%
# 한단어 사전 불러오기
df_onewords = pd.read_excel('../../datasets/한단어_concat.xlsx')
df_onewords[:5]
# Out:
#   one_char_keyword
# 0                값
# 1                꿀
# 2                꿈
# 3                끝
# 4                날

# %%
words = ' '.join(reviews_list)
words
# Out:
# '입장방식은 변경됐는데 어플은 여전히 바코드만 보여집니다. 짐에서는 더이상 바코드스캔이 아닌 어플에서 입장하기로 바뀌어 사용치 못 하고 있습니다. 매달 이용료는 나가고 있는 상황이면 고쳐지기 전까지 이용못했던 일자에 대해 보상처리는 되나요?어플을 지웠다 다시 다운 받아봐도 똑같은 상태입니다. 도대체 언제부터 전 사용 가능한가요? 정말 답답하네요 하나. GPS 100프로 신뢰하나요? 시설선택목록에서 안보임 4월말 업뎃이후 문제임 둘. 은행도 아닌데 로그인 타임아웃 적용하나요? 어디까지 사용자 불편을 감수하면서 가실려고.. 셋.충분하게 Test하고 업뎃적용하시는지? 근래 며칠이 멀다 화면이 바뀌는데 순전 관리용이지 고객은 안중에도 없어보임 뭐에 쫒기듯 어설프다 입장하려다 시설검색이 안되서 결국 다른곳에 입장했습니다. 기존에 잘 쓰던 앱이 업데이트 후에 매번 로그인 다시해야하고 위치 자동검색에 시설이 안나오고, 수동검색후 입장하는 기능도 없고 불편함만 늘었습니다. 덕분에 앱 여러번 삭제하고 다시까느라 애꿎은 데이타만 잔뜩쓰고 다시 예전 앱으로 돌아가고 싶습니다 평소 이동이 잦고 여러장소에서 운동하는걸 좋아하는 저에게는 합리적인 아이코젠이 정말 딱입니다! 제휴 업체도 꾸준히 추가되서 새로운 업체 방문하는게 요즘 낙이네요. 입장방식도 바코드에서 GPS로 바뀌면서 좀 더 편해지고 사용자편의적으로 개선이 되어가고 있어서 좋습니다. 앞으로도 좋은 제휴업체 많이 추가해주세요!!!! 아이코젠 덕분에 운동이 더 즐겁고 꾸준하게 하게 되었어요. 사용기록이 꼼꼼히 남고 사용지점이 많아서 출장이나 본가에 가게되도 지속적으로 쓸수있는점이 짱이예요! 라이프 코스도 같이 이용중인데 덕분에 카페이용비가 확 낮아졌어요 완전 대박 😀😀 작년부터 계속 이용하고 있는 아이코젠, 정말 좋아요. 축 처져있는 여름날씨에도 운동하게 만들어줘요. 앱이 누구나 알아보기 쉽고 편리하게 되어 있어요. 이용내역을 통해 내가 언제 얼마나 이용했는지 정확하게 알 수 있어서 코로나로 힘든 시국에도 편리하고 안전하게 
# ...

# %%
stopwords = df_stopwords['stopword'].values
onewords = df_onewords['one_char_keyword'].values

# 불용어, 한단어 처리 함수
def remove_words(raw, stopword=stopwords, oneword=onewords):
    list = list()
    try : 
        for word in mecab.nouns(raw) :
            if word not in stopword:
                result_list.append(word)
            # if word in stopword :
            #     result_lsit.append(word)
    except:
        pass
    return ' '.join(result_list)

# %%
df['reviews'].apply(tokenizer)
# Out:
# 0
# 1
# 2
# 3
# 4
#        ..
# 1089
# 1090
# 1091
# 1092
# 1093
# Name: reviews, Length: 1094, dtype: object

# %%
tokenizer('입장방식은 변경됐는데 어플은 여전히 바코드만 보여집니다.')
# Out:
# ''

# %% [markdown]
# #### 머신러닝 학습 후 목표변수 생성
# - stars 결측값 채우기

# %%
df.info()

# %%
df = df.dropna()
df.isnull().sum()

# %%
df.info()

# %%
df_stars = df['stars']
stars_list = df_stars.tolist()
stars_list[:10]

# %% [markdown]
# ##### 정규표현식을 사용하여 뒤에 있는 숫자 추출

# %%
import re

rating_list = list()
for stars in stars_list:
    numbers = re.findall(r'\d+', str(stars))  # 정규표현식을 사용하여 숫자만 추출
    if numbers :
        rating = int(numbers[-1])   # 추출된 숫자 중 마지막 요소인 문자열 형태의 숫자를 정수로 변환
        rating_list.append(rating)
rating_list

# %%
df_rating = pd.DataFrame(data=rating_list, columns=['rating'])
df_rating[:3]

# %% [markdown]
# ##### 병합

# %%
df = pd.concat([df, df_rating], axis=1)
df[:3]

# %% [markdown]
# ##### 목표변수 생성

# %%
target = ['긍정'] * len(positive_list) + ['부정'] * len(negative_list)
target

# %% [markdown]
# ##### 머신러닝 학습

# %%
from sklearn.svm import SVC

# %%
model = SVC()
model.fit(features.toarray(), target

# %% [markdown]
# ##### 머신러닝을 통한 예측

# %%
# df.to_csv('../../datasets/preprocessed_data.csv')
